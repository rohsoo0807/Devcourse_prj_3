# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
import pandas as pd
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# SettingWithCopyWarning 숨기기
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# UserWarning 숨기기 (ValueWarning 포함)
warnings.simplefilter(action='ignore', category=UserWarning)

# ConvergenceWarning 숨기기
warnings.simplefilter(action='ignore', category=ConvergenceWarning)

# FutureWarning 숨기기
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA

# 데이터 로드
train = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/train_pre.csv')
test = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/test.csv')
oil = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/oil_pre.csv')
holidays = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/holidays_events.csv')

# 기름 데이터 전처리
oil['date'] = pd.to_datetime(oil['date'])
oil.set_index('date', inplace=True)

# 공휴일 데이터 전처리
holidays['date'] = pd.to_datetime(holidays['date'])
national_holidays = holidays[(holidays['locale'] == 'National') & (holidays['type'] == 'Holiday')]
national_holidays = national_holidays[['date']].drop_duplicates()

# 공휴일 여부를 나타내는 함수
def is_holiday(date):
    return 1 if date in national_holidays['date'].values else 0

# 매장 번호 범위를 지정하고 예측값을 담을 리스트 초기화
store_numbers = range(30, 55)
all_predictions = []

# 각 매장 및 제품군별 반복
for store_nbr in store_numbers:
    unique_families = train[train['store_nbr'] == store_nbr]['family'].unique()

    for family in unique_families:
        # 판매 데이터 필터링 및 인덱스 설정
        train_filtered = train[(train['store_nbr'] == store_nbr) & (train['family'] == family)]
        train_filtered['date'] = pd.to_datetime(train_filtered['date'])
        train_filtered.set_index('date', inplace=True)
        train_filtered.sort_index(inplace=True)

        # 기름 데이터 병합
        train_exog = train_filtered.join(oil, how='left')
        train_exog['dcoilwtico'].fillna(method='ffill', inplace=True)
        train_exog['dcoilwtico'].fillna(method='bfill', inplace=True)

        # 공휴일 여부 열 추가
        train_exog['is_holiday'] = train_exog.index.to_series().apply(is_holiday)

        # Auto ARIMA로 최적의 파라미터 찾기
        auto_arima_model = auto_arima(
            train_exog['sales'],
            exogenous=train_exog[['dcoilwtico', 'is_holiday']],
            start_p=1, start_q=1,
            max_p=3, max_q=3,
            seasonal=False,
            d=None,
            trace=False,
            error_action='ignore',
            suppress_warnings=True,
            stepwise=False
        )
        best_p, best_d, best_q = auto_arima_model.order

        print(f"Store {store_nbr}, Family '{family}' - Parameters: p={best_p}, d={best_d}, q={best_q}")

        # 외생 변수를 포함하여 ARIMA 모델 학습
        arima_model = ARIMA(train_exog['sales'], order=(best_p, best_d, best_q), exog=train_exog[['dcoilwtico', 'is_holiday']])
        arima_fitted = arima_model.fit()

        # 테스트 데이터 준비 및 기름 데이터 병합
        test_filtered = test[(test['store_nbr'] == store_nbr) & (test['family'] == family)]
        test_filtered['date'] = pd.to_datetime(test_filtered['date'])
        test_filtered.set_index('date', inplace=True)
        test_filtered.sort_index(inplace=True)

        test_exog = test_filtered.join(oil, how='left')
        test_exog['dcoilwtico'].fillna(method='ffill', inplace=True)

        # 테스트 데이터에 공휴일 여부 추가
        test_exog['is_holiday'] = test_exog.index.to_series().apply(is_holiday)

        # 외생 변수를 사용하여 예측
        forecast_sales = arima_fitted.forecast(steps=len(test_exog), exog=test_exog[['dcoilwtico', 'is_holiday']])
        forecast_sales = forecast_sales.clip(lower=0)

        # 예측 결과를 테스트 데이터에 추가
        test_filtered['predicted_sales'] = forecast_sales.values
        test_filtered.reset_index(inplace=True)

        # 예측 결과를 최종 결과에 추가
        all_predictions.append(test_filtered[['id', 'predicted_sales']].rename(columns={'predicted_sales': 'sales'}))


# 결과를 CSV 파일로 저장
output_path = '/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/submission_30_54.csv'
all_predictions.to_csv(output_path, index=False)
# Out:
# Store 30, Family 'AUTOMOTIVE' - Parameters: p=1, d=1, q=1
# Store 30, Family 'BEAUTY' - Parameters: p=0, d=1, q=3
# Store 30, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 30, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 30, Family 'CLEANING' - Parameters: p=3, d=1, q=1
# Store 30, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 30, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 30, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 30, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=2
# Store 30, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 30, Family 'GROCERY II' - Parameters: p=1, d=0, q=1
# Store 30, Family 'HARDWARE' - Parameters: p=0, d=1, q=3
# Store 30, Family 'LINGERIE' - Parameters: p=3, d=1, q=2
# Store 30, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=1, q=0
# Store 30, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 30, Family 'PERSONAL CARE' - Parameters: p=0, d=1, q=1
# Store 30, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 30, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 30, Family 'SEAFOOD' - Parameters: p=0, d=1, q=1
# Store 30, Family 'HOME APPLIANCES' - Parameters: p=0, d=1, q=1
# Store 30, Family 'CELEBRATION' - Parameters: p=0, d=1, q=1
# Store 30, Family 'HOME AND KITCHEN I' - Parameters: p=0, d=1, q=1
# Store 30, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=3
# Store 30, Family 'HOME CARE' - Parameters: p=3, d=1, q=2
# Store 30, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=2
# Store 30, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 30, Family 'MAGAZINES' - Parameters: p=0, d=1, q=3
# Store 30, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=2
# Store 30, Family 'LADIESWEAR' - Parameters: p=0, d=1, q=3
# Store 30, Family 'BABY CARE' - Parameters: p=1, d=1, q=2
# Store 30, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 31, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=2
# Store 31, Family 'BEAUTY' - Parameters: p=0, d=1, q=3
# Store 31, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 31, Family 'BREAD/BAKERY' - Parameters: p=3, d=1, q=1
# Store 31, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 31, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 31, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 31, Family 'EGGS' - Parameters: p=3, d=1, q=2
# Store 31, Family 'FROZEN FOODS' - Parameters: p=3, d=1, q=2
# Store 31, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 31, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 31, Family 'HARDWARE' - Parameters: p=0, d=1, q=1
# Store 31, Family 'HOME APPLIANCES' - Parameters: p=3, d=1, q=1
# Store 31, Family 'LAWN AND GARDEN' - Parameters: p=1, d=1, q=3
# Store 31, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 31, Family 'LIQUOR,WINE,BEER' - Parameters: p=1, d=0, q=2
# Store 31, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 31, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 31, Family 'POULTRY' - Parameters: p=2, d=1, q=2
# Store 31, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 31, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 31, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 31, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 31, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 31, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 31, Family 'PET SUPPLIES' - Parameters: p=0, d=1, q=2
# Store 31, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=1
# Store 31, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 31, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=3
# Store 31, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 31, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 31, Family 'BABY CARE' - Parameters: p=3, d=1, q=2
# Store 32, Family 'AUTOMOTIVE' - Parameters: p=1, d=0, q=2
# Store 32, Family 'BEAUTY' - Parameters: p=0, d=1, q=1
# Store 32, Family 'BEVERAGES' - Parameters: p=1, d=1, q=3
# Store 32, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 32, Family 'CLEANING' - Parameters: p=3, d=1, q=2
# Store 32, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 32, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 32, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 32, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=3
# Store 32, Family 'GROCERY I' - Parameters: p=1, d=1, q=3
# Store 32, Family 'GROCERY II' - Parameters: p=0, d=1, q=2
# Store 32, Family 'HARDWARE' - Parameters: p=3, d=1, q=0
# Store 32, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=1
# Store 32, Family 'LINGERIE' - Parameters: p=0, d=1, q=3
# Store 32, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=1, q=2
# Store 32, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 32, Family 'PERSONAL CARE' - Parameters: p=1, d=1, q=1
# Store 32, Family 'POULTRY' - Parameters: p=1, d=0, q=3
# Store 32, Family 'PREPARED FOODS' - Parameters: p=0, d=1, q=3
# Store 32, Family 'SEAFOOD' - Parameters: p=1, d=1, q=1
# Store 32, Family 'HOME AND KITCHEN I' - Parameters: p=0, d=1, q=1
# Store 32, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=1
# Store 32, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 32, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 32, Family 'CELEBRATION' - Parameters: p=0, d=1, q=2
# Store 32, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 32, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 32, Family 'MAGAZINES' - Parameters: p=1, d=1, q=1
# Store 32, Family 'BABY CARE' - Parameters: p=1, d=0, q=1
# Store 32, Family 'LAWN AND GARDEN' - Parameters: p=1, d=0, q=3
# Store 32, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=2, d=1, q=2
# Store 33, Family 'AUTOMOTIVE' - Parameters: p=3, d=1, q=1
# Store 33, Family 'BEAUTY' - Parameters: p=1, d=1, q=2
# Store 33, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 33, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 33, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 33, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 33, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 33, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 33, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 33, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 33, Family 'GROCERY II' - Parameters: p=3, d=1, q=2
# Store 33, Family 'LINGERIE' - Parameters: p=1, d=1, q=1
# Store 33, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 33, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 33, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 33, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 33, Family 'PREPARED FOODS' - Parameters: p=0, d=1, q=2
# Store 33, Family 'SEAFOOD' - Parameters: p=3, d=1, q=2
# Store 33, Family 'HOME APPLIANCES' - Parameters: p=0, d=1, q=1
# Store 33, Family 'HARDWARE' - Parameters: p=1, d=1, q=2
# Store 33, Family 'CELEBRATION' - Parameters: p=0, d=1, q=1
# Store 33, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 33, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 33, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 33, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 33, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 33, Family 'MAGAZINES' - Parameters: p=0, d=1, q=3
# Store 33, Family 'PET SUPPLIES' - Parameters: p=0, d=1, q=2
# Store 33, Family 'LAWN AND GARDEN' - Parameters: p=1, d=1, q=1
# Store 33, Family 'BABY CARE' - Parameters: p=0, d=1, q=1
# Store 33, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=2, d=0, q=3
# Store 34, Family 'AUTOMOTIVE' - Parameters: p=1, d=1, q=1
# Store 34, Family 'BEAUTY' - Parameters: p=2, d=1, q=1
# Store 34, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 34, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 34, Family 'CLEANING' - Parameters: p=0, d=1, q=3
# Store 34, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 34, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 34, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 34, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=3
# Store 34, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 34, Family 'GROCERY II' - Parameters: p=2, d=1, q=1
# Store 34, Family 'HARDWARE' - Parameters: p=3, d=1, q=1
# Store 34, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=1
# Store 34, Family 'LINGERIE' - Parameters: p=1, d=1, q=1
# Store 34, Family 'LIQUOR,WINE,BEER' - Parameters: p=0, d=1, q=3
# Store 34, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 34, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 34, Family 'PREPARED FOODS' - Parameters: p=0, d=1, q=2
# Store 34, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 34, Family 'SEAFOOD' - Parameters: p=2, d=1, q=2
# Store 34, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=1
# Store 34, Family 'CELEBRATION' - Parameters: p=2, d=0, q=3
# Store 34, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=2
# Store 34, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 34, Family 'HOME CARE' - Parameters: p=0, d=1, q=3
# Store 34, Family 'LADIESWEAR' - Parameters: p=0, d=1, q=2
# Store 34, Family 'PET SUPPLIES' - Parameters: p=1, d=1, q=1
# Store 34, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=3
# Store 34, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 34, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 34, Family 'MAGAZINES' - Parameters: p=1, d=1, q=2
# Store 34, Family 'BABY CARE' - Parameters: p=0, d=1, q=3
# Store 35, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 35, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 35, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 35, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 35, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 35, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 35, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 35, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 35, Family 'GROCERY I' - Parameters: p=3, d=1, q=0
# Store 35, Family 'GROCERY II' - Parameters: p=2, d=1, q=1
# Store 35, Family 'LINGERIE' - Parameters: p=1, d=1, q=2
# Store 35, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=2
# Store 35, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 35, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 35, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 35, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 35, Family 'HARDWARE' - Parameters: p=0, d=1, q=1
# Store 35, Family 'SEAFOOD' - Parameters: p=3, d=0, q=1
# Store 35, Family 'BEAUTY' - Parameters: p=3, d=1, q=0
# Store 35, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=1
# Store 35, Family 'CELEBRATION' - Parameters: p=0, d=1, q=1
# Store 35, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=1
# Store 35, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=1
# Store 35, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 35, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 35, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=0, d=1, q=2
# Store 35, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 35, Family 'MAGAZINES' - Parameters: p=1, d=1, q=1
# Store 35, Family 'LAWN AND GARDEN' - Parameters: p=1, d=0, q=0
# Store 35, Family 'BABY CARE' - Parameters: p=0, d=1, q=3
# Store 35, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=0, q=3
# Store 36, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=2
# Store 36, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 36, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 36, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 36, Family 'CLEANING' - Parameters: p=3, d=1, q=2
# Store 36, Family 'DAIRY' - Parameters: p=3, d=1, q=1
# Store 36, Family 'DELI' - Parameters: p=3, d=1, q=2
# Store 36, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 36, Family 'FROZEN FOODS' - Parameters: p=1, d=1, q=1
# Store 36, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 36, Family 'GROCERY II' - Parameters: p=3, d=0, q=2
# Store 36, Family 'HARDWARE' - Parameters: p=1, d=0, q=1
# Store 36, Family 'LINGERIE' - Parameters: p=3, d=1, q=2
# Store 36, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=1, q=2
# Store 36, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 36, Family 'PERSONAL CARE' - Parameters: p=1, d=1, q=3
# Store 36, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 36, Family 'PREPARED FOODS' - Parameters: p=3, d=1, q=2
# Store 36, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 36, Family 'HOME APPLIANCES' - Parameters: p=0, d=1, q=1
# Store 36, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 36, Family 'CELEBRATION' - Parameters: p=1, d=1, q=2
# Store 36, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=1
# Store 36, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 36, Family 'HOME CARE' - Parameters: p=1, d=1, q=3
# Store 36, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 36, Family 'PET SUPPLIES' - Parameters: p=1, d=1, q=3
# Store 36, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=2
# Store 36, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 36, Family 'MAGAZINES' - Parameters: p=1, d=1, q=2
# Store 36, Family 'LADIESWEAR' - Parameters: p=1, d=1, q=3
# Store 36, Family 'BABY CARE' - Parameters: p=0, d=1, q=1
# Store 37, Family 'AUTOMOTIVE' - Parameters: p=0, d=1, q=2
# Store 37, Family 'BEAUTY' - Parameters: p=0, d=1, q=2
# Store 37, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 37, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 37, Family 'CLEANING' - Parameters: p=3, d=1, q=2
# Store 37, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 37, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 37, Family 'EGGS' - Parameters: p=3, d=1, q=1
# Store 37, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=3
# Store 37, Family 'GROCERY I' - Parameters: p=3, d=1, q=1
# Store 37, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 37, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 37, Family 'LINGERIE' - Parameters: p=2, d=1, q=2
# Store 37, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 37, Family 'MEATS' - Parameters: p=1, d=1, q=3
# Store 37, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=2
# Store 37, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 37, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 37, Family 'SEAFOOD' - Parameters: p=1, d=1, q=1
# Store 37, Family 'HARDWARE' - Parameters: p=0, d=1, q=2
# Store 37, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=1
# Store 37, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 37, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 37, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 37, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=2
# Store 37, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 37, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 37, Family 'MAGAZINES' - Parameters: p=1, d=1, q=2
# Store 37, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=2
# Store 37, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=1
# Store 37, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=1, q=2
# Store 37, Family 'BOOKS' - Parameters: p=3, d=1, q=2
# Store 37, Family 'BABY CARE' - Parameters: p=3, d=1, q=0
# Store 38, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 38, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 38, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 38, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 38, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 38, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 38, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 38, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 38, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=1
# Store 38, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 38, Family 'GROCERY II' - Parameters: p=3, d=1, q=1
# Store 38, Family 'HARDWARE' - Parameters: p=1, d=1, q=1
# Store 38, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 38, Family 'LINGERIE' - Parameters: p=2, d=1, q=2
# Store 38, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 38, Family 'MEATS' - Parameters: p=3, d=1, q=1
# Store 38, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 38, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 38, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 38, Family 'SEAFOOD' - Parameters: p=3, d=1, q=2
# Store 38, Family 'PRODUCE' - Parameters: p=3, d=1, q=2
# Store 38, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 38, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=1
# Store 38, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 38, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 38, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 38, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 38, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 38, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 38, Family 'HOME APPLIANCES' - Parameters: p=0, d=1, q=2
# Store 38, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=1
# Store 38, Family 'BABY CARE' - Parameters: p=2, d=0, q=0
# Store 38, Family 'BOOKS' - Parameters: p=0, d=1, q=1
# Store 39, Family 'AUTOMOTIVE' - Parameters: p=3, d=1, q=0
# Store 39, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 39, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 39, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 39, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 39, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 39, Family 'DELI' - Parameters: p=3, d=1, q=1
# Store 39, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 39, Family 'FROZEN FOODS' - Parameters: p=0, d=1, q=3
# Store 39, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 39, Family 'GROCERY II' - Parameters: p=3, d=1, q=2
# Store 39, Family 'HARDWARE' - Parameters: p=1, d=0, q=1
# Store 39, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=3
# Store 39, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 39, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 39, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 39, Family 'MEATS' - Parameters: p=3, d=1, q=0
# Store 39, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=2
# Store 39, Family 'POULTRY' - Parameters: p=3, d=1, q=2
# Store 39, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 39, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 39, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 39, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=1
# Store 39, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=1
# Store 39, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 39, Family 'LADIESWEAR' - Parameters: p=3, d=1, q=2
# Store 39, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 39, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=0, d=1, q=2
# Store 39, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 39, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=0, q=2
# Store 39, Family 'MAGAZINES' - Parameters: p=1, d=1, q=1
# Store 39, Family 'BABY CARE' - Parameters: p=2, d=1, q=3
# Store 40, Family 'AUTOMOTIVE' - Parameters: p=0, d=1, q=2
# Store 40, Family 'BEAUTY' - Parameters: p=1, d=1, q=2
# Store 40, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 40, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 40, Family 'CLEANING' - Parameters: p=3, d=1, q=2
# Store 40, Family 'DAIRY' - Parameters: p=3, d=1, q=2
# Store 40, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 40, Family 'EGGS' - Parameters: p=3, d=1, q=2
# Store 40, Family 'FROZEN FOODS' - Parameters: p=1, d=1, q=3
# Store 40, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 40, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 40, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 40, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 40, Family 'PERSONAL CARE' - Parameters: p=3, d=1, q=2
# Store 40, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 40, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 40, Family 'SEAFOOD' - Parameters: p=1, d=1, q=1
# Store 40, Family 'LINGERIE' - Parameters: p=1, d=1, q=1
# Store 40, Family 'HARDWARE' - Parameters: p=1, d=1, q=3
# Store 40, Family 'HOME APPLIANCES' - Parameters: p=3, d=1, q=1
# Store 40, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 40, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=1
# Store 40, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 40, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 40, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 40, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=0, d=1, q=1
# Store 40, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 40, Family 'MAGAZINES' - Parameters: p=2, d=1, q=1
# Store 40, Family 'LAWN AND GARDEN' - Parameters: p=1, d=0, q=0
# Store 40, Family 'BABY CARE' - Parameters: p=2, d=1, q=2
# Store 40, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 41, Family 'AUTOMOTIVE' - Parameters: p=3, d=1, q=0
# Store 41, Family 'BEAUTY' - Parameters: p=3, d=1, q=1
# Store 41, Family 'BEVERAGES' - Parameters: p=2, d=1, q=2
# Store 41, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 41, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 41, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 41, Family 'DELI' - Parameters: p=3, d=1, q=1
# Store 41, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 41, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=1
# Store 41, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 41, Family 'GROCERY II' - Parameters: p=1, d=1, q=3
# Store 41, Family 'HARDWARE' - Parameters: p=1, d=1, q=2
# Store 41, Family 'LAWN AND GARDEN' - Parameters: p=3, d=1, q=1
# Store 41, Family 'LINGERIE' - Parameters: p=1, d=1, q=1
# Store 41, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 41, Family 'MEATS' - Parameters: p=1, d=1, q=2
# Store 41, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 41, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 41, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 41, Family 'SEAFOOD' - Parameters: p=2, d=1, q=2
# Store 41, Family 'HOME APPLIANCES' - Parameters: p=1, d=1, q=1
# Store 41, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 41, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 41, Family 'HOME AND KITCHEN I' - Parameters: p=0, d=1, q=1
# Store 41, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=2
# Store 41, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 41, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 41, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 41, Family 'PET SUPPLIES' - Parameters: p=1, d=1, q=1
# Store 41, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 41, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=0, d=1, q=1
# Store 41, Family 'BABY CARE' - Parameters: p=0, d=1, q=1
# Store 41, Family 'BOOKS' - Parameters: p=1, d=1, q=2
# Store 42, Family 'AUTOMOTIVE' - Parameters: p=1, d=0, q=1
# Store 42, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 42, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 42, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 42, Family 'CELEBRATION' - Parameters: p=1, d=0, q=1
# Store 42, Family 'CLEANING' - Parameters: p=2, d=1, q=1
# Store 42, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 42, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 42, Family 'EGGS' - Parameters: p=2, d=1, q=2
# Store 42, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=2
# Store 42, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 42, Family 'GROCERY II' - Parameters: p=0, d=1, q=2
# Store 42, Family 'HARDWARE' - Parameters: p=1, d=0, q=2
# Store 42, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=0, q=1
# Store 42, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 42, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 42, Family 'LADIESWEAR' - Parameters: p=3, d=0, q=2
# Store 42, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 42, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 42, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 42, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 42, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 42, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 42, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 42, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=1
# Store 42, Family 'POULTRY' - Parameters: p=3, d=1, q=2
# Store 42, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 42, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 42, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 42, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 42, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=0, q=1
# Store 42, Family 'BABY CARE' - Parameters: p=2, d=0, q=2
# Store 42, Family 'BOOKS' - Parameters: p=2, d=1, q=3
# Store 43, Family 'AUTOMOTIVE' - Parameters: p=0, d=1, q=2
# Store 43, Family 'BEAUTY' - Parameters: p=1, d=1, q=2
# Store 43, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 43, Family 'BREAD/BAKERY' - Parameters: p=3, d=1, q=1
# Store 43, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 43, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 43, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 43, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 43, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 43, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 43, Family 'GROCERY II' - Parameters: p=3, d=1, q=1
# Store 43, Family 'LINGERIE' - Parameters: p=1, d=1, q=2
# Store 43, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=0, q=1
# Store 43, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 43, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 43, Family 'POULTRY' - Parameters: p=3, d=1, q=0
# Store 43, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 43, Family 'HARDWARE' - Parameters: p=3, d=1, q=1
# Store 43, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 43, Family 'HOME APPLIANCES' - Parameters: p=3, d=1, q=0
# Store 43, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 43, Family 'HOME AND KITCHEN I' - Parameters: p=0, d=1, q=3
# Store 43, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=2
# Store 43, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 43, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=2
# Store 43, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 43, Family 'MAGAZINES' - Parameters: p=0, d=1, q=1
# Store 43, Family 'PET SUPPLIES' - Parameters: p=1, d=1, q=2
# Store 43, Family 'LAWN AND GARDEN' - Parameters: p=0, d=1, q=2
# Store 43, Family 'BABY CARE' - Parameters: p=2, d=0, q=3
# Store 43, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 44, Family 'AUTOMOTIVE' - Parameters: p=3, d=1, q=2
# Store 44, Family 'BEAUTY' - Parameters: p=3, d=1, q=2
# Store 44, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 44, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 44, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 44, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 44, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 44, Family 'EGGS' - Parameters: p=2, d=1, q=2
# Store 44, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=2
# Store 44, Family 'GROCERY I' - Parameters: p=2, d=1, q=2
# Store 44, Family 'GROCERY II' - Parameters: p=3, d=0, q=2
# Store 44, Family 'HARDWARE' - Parameters: p=3, d=0, q=1
# Store 44, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=3
# Store 44, Family 'LINGERIE' - Parameters: p=3, d=0, q=1
# Store 44, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 44, Family 'MEATS' - Parameters: p=3, d=0, q=2
# Store 44, Family 'PERSONAL CARE' - Parameters: p=3, d=1, q=2
# Store 44, Family 'POULTRY' - Parameters: p=3, d=1, q=1
# Store 44, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 44, Family 'SEAFOOD' - Parameters: p=3, d=1, q=2
# Store 44, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 44, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 44, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 44, Family 'HOME AND KITCHEN I' - Parameters: p=0, d=1, q=1
# Store 44, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=2
# Store 44, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 44, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=2
# Store 44, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 44, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 44, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=1, q=3
# Store 44, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=1, q=2
# Store 44, Family 'BOOKS' - Parameters: p=0, d=1, q=1
# Store 45, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 45, Family 'BEAUTY' - Parameters: p=3, d=1, q=2
# Store 45, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 45, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 45, Family 'CLEANING' - Parameters: p=2, d=1, q=2
# Store 45, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 45, Family 'DELI' - Parameters: p=3, d=1, q=2
# Store 45, Family 'EGGS' - Parameters: p=2, d=1, q=2
# Store 45, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=3
# Store 45, Family 'GROCERY I' - Parameters: p=0, d=1, q=1
# Store 45, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 45, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 45, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=2
# Store 45, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 45, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 45, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 45, Family 'PERSONAL CARE' - Parameters: p=3, d=1, q=2
# Store 45, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 45, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 45, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 45, Family 'HARDWARE' - Parameters: p=2, d=1, q=2
# Store 45, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 45, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 45, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 45, Family 'HOME AND KITCHEN II' - Parameters: p=0, d=1, q=3
# Store 45, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 45, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 45, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 45, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 45, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 45, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 45, Family 'BOOKS' - Parameters: p=3, d=1, q=2
# Store 46, Family 'AUTOMOTIVE' - Parameters: p=3, d=0, q=1
# Store 46, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 46, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 46, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 46, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 46, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 46, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 46, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 46, Family 'FROZEN FOODS' - Parameters: p=1, d=0, q=3
# Store 46, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 46, Family 'GROCERY II' - Parameters: p=2, d=1, q=2
# Store 46, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 46, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=1
# Store 46, Family 'LINGERIE' - Parameters: p=3, d=1, q=2
# Store 46, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=0, q=2
# Store 46, Family 'MEATS' - Parameters: p=3, d=1, q=1
# Store 46, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 46, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 46, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=2
# Store 46, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 46, Family 'HARDWARE' - Parameters: p=0, d=1, q=2
# Store 46, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 46, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 46, Family 'HOME AND KITCHEN I' - Parameters: p=3, d=1, q=1
# Store 46, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=2
# Store 46, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 46, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 46, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 46, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 46, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=0, d=1, q=3
# Store 46, Family 'MAGAZINES' - Parameters: p=1, d=1, q=3
# Store 46, Family 'BOOKS' - Parameters: p=3, d=1, q=2
# Store 47, Family 'AUTOMOTIVE' - Parameters: p=3, d=0, q=1
# Store 47, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 47, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 47, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 47, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 47, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 47, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 47, Family 'EGGS' - Parameters: p=2, d=1, q=2
# Store 47, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=2
# Store 47, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 47, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 47, Family 'HARDWARE' - Parameters: p=2, d=1, q=3
# Store 47, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=2
# Store 47, Family 'LINGERIE' - Parameters: p=1, d=1, q=2
# Store 47, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=2
# Store 47, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 47, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 47, Family 'POULTRY' - Parameters: p=3, d=1, q=1
# Store 47, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 47, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 47, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 47, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 47, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 47, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=3
# Store 47, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 47, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 47, Family 'LADIESWEAR' - Parameters: p=3, d=1, q=2
# Store 47, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 47, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 47, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 47, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 47, Family 'BOOKS' - Parameters: p=0, d=1, q=1
# Store 48, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 48, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 48, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 48, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=2
# Store 48, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 48, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 48, Family 'DELI' - Parameters: p=3, d=1, q=1
# Store 48, Family 'EGGS' - Parameters: p=0, d=1, q=1
# Store 48, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=1
# Store 48, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 48, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 48, Family 'HARDWARE' - Parameters: p=0, d=1, q=3
# Store 48, Family 'LAWN AND GARDEN' - Parameters: p=0, d=1, q=2
# Store 48, Family 'LINGERIE' - Parameters: p=3, d=1, q=1
# Store 48, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=2
# Store 48, Family 'MEATS' - Parameters: p=2, d=0, q=3
# Store 48, Family 'PERSONAL CARE' - Parameters: p=3, d=1, q=2
# Store 48, Family 'POULTRY' - Parameters: p=3, d=1, q=2
# Store 48, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=2
# Store 48, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 48, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 48, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 48, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 48, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=2
# Store 48, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 48, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 48, Family 'LADIESWEAR' - Parameters: p=3, d=1, q=2
# Store 48, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 48, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 48, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 48, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 48, Family 'BOOKS' - Parameters: p=3, d=1, q=1
# Store 49, Family 'AUTOMOTIVE' - Parameters: p=0, d=1, q=2
# Store 49, Family 'BEAUTY' - Parameters: p=3, d=1, q=2
# Store 49, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 49, Family 'BREAD/BAKERY' - Parameters: p=3, d=1, q=1
# Store 49, Family 'CLEANING' - Parameters: p=3, d=1, q=1
# Store 49, Family 'DAIRY' - Parameters: p=2, d=1, q=2
# Store 49, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 49, Family 'EGGS' - Parameters: p=3, d=1, q=1
# Store 49, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 49, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 49, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 49, Family 'HARDWARE' - Parameters: p=2, d=1, q=1
# Store 49, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 49, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 49, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 49, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 49, Family 'POULTRY' - Parameters: p=3, d=1, q=1
# Store 49, Family 'PREPARED FOODS' - Parameters: p=3, d=1, q=2
# Store 49, Family 'SEAFOOD' - Parameters: p=3, d=1, q=1
# Store 49, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=1
# Store 49, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=2
# Store 49, Family 'PRODUCE' - Parameters: p=3, d=1, q=2
# Store 49, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 49, Family 'HOME AND KITCHEN I' - Parameters: p=3, d=1, q=2
# Store 49, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=1
# Store 49, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 49, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 49, Family 'MAGAZINES' - Parameters: p=2, d=1, q=3
# Store 49, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 49, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 49, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 49, Family 'BOOKS' - Parameters: p=1, d=1, q=3
# Store 50, Family 'AUTOMOTIVE' - Parameters: p=3, d=0, q=0
# Store 50, Family 'BEAUTY' - Parameters: p=1, d=1, q=2
# Store 50, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 50, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 50, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 50, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 50, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 50, Family 'EGGS' - Parameters: p=2, d=1, q=2
# Store 50, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=2
# Store 50, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 50, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 50, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 50, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=1, q=3
# Store 50, Family 'MEATS' - Parameters: p=2, d=1, q=3
# Store 50, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 50, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 50, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 50, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 50, Family 'HARDWARE' - Parameters: p=2, d=1, q=3
# Store 50, Family 'LAWN AND GARDEN' - Parameters: p=0, d=1, q=2
# Store 50, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=3
# Store 50, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 50, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 50, Family 'HOME AND KITCHEN I' - Parameters: p=3, d=1, q=1
# Store 50, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=1
# Store 50, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 50, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 50, Family 'MAGAZINES' - Parameters: p=1, d=1, q=3
# Store 50, Family 'PET SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 50, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 50, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=3, d=1, q=2
# Store 50, Family 'BOOKS' - Parameters: p=1, d=1, q=3
# Store 51, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 51, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 51, Family 'BEVERAGES' - Parameters: p=2, d=1, q=2
# Store 51, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 51, Family 'CLEANING' - Parameters: p=2, d=1, q=3
# Store 51, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 51, Family 'DELI' - Parameters: p=3, d=1, q=1
# Store 51, Family 'EGGS' - Parameters: p=3, d=1, q=2
# Store 51, Family 'FROZEN FOODS' - Parameters: p=2, d=0, q=3
# Store 51, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 51, Family 'GROCERY II' - Parameters: p=1, d=0, q=2
# Store 51, Family 'HARDWARE' - Parameters: p=0, d=1, q=1
# Store 51, Family 'LAWN AND GARDEN' - Parameters: p=2, d=1, q=2
# Store 51, Family 'LINGERIE' - Parameters: p=3, d=1, q=1
# Store 51, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=0, q=2
# Store 51, Family 'MEATS' - Parameters: p=3, d=0, q=2
# Store 51, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 51, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 51, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 51, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 51, Family 'HOME APPLIANCES' - Parameters: p=1, d=0, q=1
# Store 51, Family 'PRODUCE' - Parameters: p=3, d=1, q=2
# Store 51, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 51, Family 'HOME AND KITCHEN I' - Parameters: p=1, d=1, q=1
# Store 51, Family 'HOME AND KITCHEN II' - Parameters: p=3, d=1, q=1
# Store 51, Family 'HOME CARE' - Parameters: p=3, d=1, q=2
# Store 51, Family 'LADIESWEAR' - Parameters: p=2, d=1, q=3
# Store 51, Family 'MAGAZINES' - Parameters: p=1, d=1, q=1
# Store 51, Family 'PET SUPPLIES' - Parameters: p=0, d=1, q=2
# Store 51, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 51, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=1, q=3
# Store 51, Family 'BOOKS' - Parameters: p=1, d=1, q=2
# Store 52, Family 'AUTOMOTIVE' - Parameters: p=3, d=0, q=0
# Store 52, Family 'BEAUTY' - Parameters: p=3, d=0, q=0
# Store 52, Family 'BEVERAGES' - Parameters: p=2, d=0, q=1
# Store 52, Family 'BREAD/BAKERY' - Parameters: p=1, d=0, q=3
# Store 52, Family 'CELEBRATION' - Parameters: p=1, d=0, q=1
# Store 52, Family 'CLEANING' - Parameters: p=3, d=0, q=1
# Store 52, Family 'DAIRY' - Parameters: p=1, d=0, q=3
# Store 52, Family 'DELI' - Parameters: p=2, d=0, q=1
# Store 52, Family 'EGGS' - Parameters: p=2, d=0, q=1
# Store 52, Family 'FROZEN FOODS' - Parameters: p=3, d=0, q=2
# Store 52, Family 'GROCERY I' - Parameters: p=3, d=0, q=1
# Store 52, Family 'GROCERY II' - Parameters: p=3, d=1, q=1
# Store 52, Family 'HARDWARE' - Parameters: p=3, d=0, q=0
# Store 52, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=0, q=1
# Store 52, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 52, Family 'HOME APPLIANCES' - Parameters: p=2, d=1, q=0
# Store 52, Family 'HOME CARE' - Parameters: p=3, d=0, q=1
# Store 52, Family 'LADIESWEAR' - Parameters: p=3, d=1, q=1
# Store 52, Family 'LAWN AND GARDEN' - Parameters: p=1, d=0, q=0
# Store 52, Family 'LINGERIE' - Parameters: p=1, d=0, q=2
# Store 52, Family 'LIQUOR,WINE,BEER' - Parameters: p=3, d=1, q=0
# Store 52, Family 'MAGAZINES' - Parameters: p=3, d=1, q=2
# Store 52, Family 'MEATS' - Parameters: p=1, d=0, q=3
# Store 52, Family 'PERSONAL CARE' - Parameters: p=3, d=1, q=1
# Store 52, Family 'PET SUPPLIES' - Parameters: p=1, d=0, q=2
# Store 52, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=1, d=0, q=2
# Store 52, Family 'POULTRY' - Parameters: p=3, d=0, q=2
# Store 52, Family 'PREPARED FOODS' - Parameters: p=1, d=0, q=1
# Store 52, Family 'PRODUCE' - Parameters: p=3, d=0, q=2
# Store 52, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=1, q=3
# Store 52, Family 'SEAFOOD' - Parameters: p=1, d=0, q=1
# Store 53, Family 'AUTOMOTIVE' - Parameters: p=2, d=1, q=3
# Store 53, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 53, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# Store 53, Family 'BREAD/BAKERY' - Parameters: p=2, d=1, q=3
# Store 53, Family 'CLEANING' - Parameters: p=1, d=1, q=2
# Store 53, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 53, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 53, Family 'EGGS' - Parameters: p=2, d=1, q=3
# Store 53, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 53, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 53, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 53, Family 'HARDWARE' - Parameters: p=0, d=1, q=1
# Store 53, Family 'HOME APPLIANCES' - Parameters: p=1, d=1, q=2
# Store 53, Family 'LAWN AND GARDEN' - Parameters: p=1, d=1, q=2
# Store 53, Family 'LINGERIE' - Parameters: p=0, d=0, q=3
# Store 53, Family 'LIQUOR,WINE,BEER' - Parameters: p=2, d=0, q=3
# Store 53, Family 'MEATS' - Parameters: p=3, d=1, q=1
# Store 53, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 53, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 53, Family 'PREPARED FOODS' - Parameters: p=2, d=1, q=3
# Store 53, Family 'PRODUCE' - Parameters: p=2, d=1, q=3
# Store 53, Family 'SEAFOOD' - Parameters: p=2, d=1, q=3
# Store 53, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 53, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 53, Family 'HOME AND KITCHEN II' - Parameters: p=1, d=1, q=2
# Store 53, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 53, Family 'LADIESWEAR' - Parameters: p=1, d=1, q=3
# Store 53, Family 'MAGAZINES' - Parameters: p=2, d=1, q=2
# Store 53, Family 'PET SUPPLIES' - Parameters: p=1, d=1, q=1
# Store 53, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=2, d=1, q=3
# Store 53, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=2, d=1, q=3
# Store 53, Family 'BABY CARE' - Parameters: p=3, d=0, q=2
# Store 53, Family 'BOOKS' - Parameters: p=0, d=1, q=1
# Store 54, Family 'AUTOMOTIVE' - Parameters: p=1, d=1, q=1
# Store 54, Family 'BEVERAGES' - Parameters: p=3, d=1, q=2
# Store 54, Family 'BREAD/BAKERY' - Parameters: p=3, d=1, q=1
# Store 54, Family 'CLEANING' - Parameters: p=3, d=1, q=1
# Store 54, Family 'DAIRY' - Parameters: p=2, d=1, q=3
# Store 54, Family 'DELI' - Parameters: p=2, d=1, q=3
# Store 54, Family 'EGGS' - Parameters: p=3, d=1, q=2
# Store 54, Family 'FROZEN FOODS' - Parameters: p=2, d=1, q=3
# Store 54, Family 'GROCERY I' - Parameters: p=2, d=1, q=3
# Store 54, Family 'GROCERY II' - Parameters: p=2, d=1, q=3
# Store 54, Family 'HOME APPLIANCES' - Parameters: p=0, d=1, q=1
# Store 54, Family 'LIQUOR,WINE,BEER' - Parameters: p=1, d=0, q=2
# Store 54, Family 'MEATS' - Parameters: p=3, d=1, q=2
# Store 54, Family 'PERSONAL CARE' - Parameters: p=2, d=1, q=3
# Store 54, Family 'POULTRY' - Parameters: p=2, d=1, q=3
# Store 54, Family 'PREPARED FOODS' - Parameters: p=3, d=1, q=2
# Store 54, Family 'SEAFOOD' - Parameters: p=3, d=0, q=1
# Store 54, Family 'HARDWARE' - Parameters: p=3, d=0, q=0
# Store 54, Family 'LINGERIE' - Parameters: p=2, d=1, q=3
# Store 54, Family 'BEAUTY' - Parameters: p=0, d=1, q=3
# Store 54, Family 'CELEBRATION' - Parameters: p=2, d=1, q=3
# Store 54, Family 'HOME AND KITCHEN I' - Parameters: p=2, d=1, q=3
# Store 54, Family 'HOME AND KITCHEN II' - Parameters: p=2, d=1, q=3
# Store 54, Family 'HOME CARE' - Parameters: p=2, d=1, q=3
# Store 54, Family 'PLAYERS AND ELECTRONICS' - Parameters: p=0, d=1, q=3
# Store 54, Family 'PRODUCE' - Parameters: p=3, d=1, q=2
# Store 54, Family 'PET SUPPLIES' - Parameters: p=0, d=1, q=1
# Store 54, Family 'MAGAZINES' - Parameters: p=2, d=1, q=2
# Store 54, Family 'BABY CARE' - Parameters: p=2, d=1, q=3
# Store 54, Family 'SCHOOL AND OFFICE SUPPLIES' - Parameters: p=1, d=1, q=2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a5fcc4fca870> in <cell line: 94>()
#      92 # 결과를 CSV 파일로 저장
#      93 output_path = '/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/submission_30_54.csv'
# ---> 94 all_predictions.to_csv(output_path, index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
submission = pd.concat(all_predictions, ignore_index=True)
output_path = '/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/submission_30_54.csv'
submission.to_csv(output_path, index=False)

# %%
import pandas as pd
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA

# 데이터 로드
train = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/train_pre.csv')
test = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/test.csv')
oil = pd.read_csv('/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/oil_pre.csv')

# 기름 데이터 전처리
oil['date'] = pd.to_datetime(oil['date'])
oil.set_index('date', inplace=True)

# 매장 번호 범위를 지정하고 예측값을 담을 리스트 초기화
store_numbers = range(1, 38)
all_predictions = []

# 각 매장 및 제품군별 반복
for store_nbr in store_numbers:
    unique_families = train[train['store_nbr'] == store_nbr]['family'].unique()

    for family in unique_families:
        # 판매 데이터 필터링 및 인덱스 설정
        train_filtered = train[(train['store_nbr'] == store_nbr) & (train['family'] == family)]
        train_filtered['date'] = pd.to_datetime(train_filtered['date'])
        train_filtered.set_index('date', inplace=True)
        train_filtered.sort_index(inplace=True)

        # 기름 데이터 병합
        train_exog = train_filtered.join(oil, how='left')
        train_exog['dcoilwtico'].fillna(method='ffill', inplace=True)
        train_exog['dcoilwtico'].fillna(method='bfill', inplace=True)

        # Auto ARIMA로 최적의 파라미터 찾기
        auto_arima_model = auto_arima(
            train_exog['sales'],
            exogenous=train_exog[['dcoilwtico']],
            start_p=1, start_q=1,
            max_p=3, max_q=3,
            seasonal=False,
            d=None,
            trace=False,
            error_action='ignore',
            suppress_warnings=True,
            stepwise=False
        )
        best_p, best_d, best_q = auto_arima_model.order

        print(f"Store {store_nbr}, Family '{family}' - Parameters: p={best_p}, d={best_d}, q={best_q}")

        # ARIMA 모델 학습
        arima_model = ARIMA(train_exog['sales'], order=(best_p, best_d, best_q), exog=train_exog[['dcoilwtico']])
        arima_fitted = arima_model.fit()

        # 예측 결과를 테스트 데이터에 추가
        test_filtered['predicted_sales'] = forecast_sales.values
        test_filtered.reset_index(inplace=True)

        # 예측 결과를 최종 결과에 추가
        all_predictions.append(test_filtered[['id', 'predicted_sales']].rename(columns={'predicted_sales': 'sales'}))

submission = pd.concat(all_predictions, ignore_index=True)
# 결과를 CSV 파일로 저장
output_path = '/content/drive/MyDrive/Dev_course/3차 팀 프로젝트/submission_nor1_27.csv'
all_predictions.to_csv(output_path, index=False)
# Out:
# Store 1, Family 'AUTOMOTIVE' - Parameters: p=0, d=1, q=3
# Store 1, Family 'BEAUTY' - Parameters: p=2, d=1, q=3
# Store 1, Family 'BEVERAGES' - Parameters: p=2, d=1, q=3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5408f53edf1b> in <cell line: 19>()
#      55         # 예측 결과를 테스트 데이터에 추가
#      56         test_filtered['predicted_sales'] = forecast_sales.values
# ---> 57         test_filtered.reset_index(inplace=True)
#      58
#      59         # 예측 결과를 최종 결과에 추가
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6207                     )
#    6208
# -> 6209                 new_obj.insert(
#    6210                     0,
#    6211                     name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists
